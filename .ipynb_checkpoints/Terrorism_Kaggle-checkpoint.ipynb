# %% [markdown]
# ## <center>Data exploration</center>
# # <center>Global Terrorism Database</center>
# ## <center> Michał Kwiatosz </center>
# ### <div style="text-align: right"> 11.03.2019r </div>
#
# ![title](img/terror.jpg)

# %%
# Dependencies 
import numpy as np
import pandas as pd
import plotly.offline as py
import csv 
import plotly.graph_objs as go
import seaborn as sns
import matplotlib.pyplot as plt
import json
import os
import folium
from folium.plugins import MarkerCluster
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading data
terror=pd.read_csv('../gtd/globalterrorismdb_0718dist.csv' ,encoding='ISO-8859-1')
print("Data before extraction to specific columns: ",terror.shape)

# Rename columns which will be used + add 
terror.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# Columns used
terror=terror[['Year','Month','Day','Country','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# Add column casualities
terror['casualities']=terror['Killed']+terror['Wounded']
# Out:
# Data before extraction to specific columns:  (181691, 135)

# %%
# Shape after 
print("Data after extraction to specific columns: ",terror.shape)
# Out:
# Data after extraction to specific columns:  (181691, 18)

# %%
# What kind of data do we have
terror.get_dtype_counts()
# Out:
# float64     5
# int64       3
# object     10
# dtype: int64

# %% [markdown]
# # <center>Terrorism Worldwide</center>

# %%
# First 10 values
terror.head(10)
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
# 5  1970      1    1       United States                North America
# 6  1970      1    2             Uruguay                South America
# 7  1970      1    2       United States                North America
# 8  1970      1    2       United States                North America
# 9  1970      1    3       United States                North America
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# ...

# %%
print('Country with Highest Terrorist Attacks:',terror['Country'].value_counts().index[0])
print('Month with Highest Terrorist Attacks:',terror['Month'].value_counts().index[0])
print('Day with Highest Terrorist Attacks:',terror['Day'].value_counts().index[0])
print('Region with Highest Terrorist Attacks:',terror['Region'].value_counts().index[0])
# Out:
# Country with Highest Terrorist Attacks: Iraq
# Month with Highest Terrorist Attacks: 5
# Day with Highest Terrorist Attacks: 15
# Region with Highest Terrorist Attacks: Middle East & North Africa

# %% [markdown]
# #### Country - Iraq - Muslim
# #### Month - 5 - Muslims starts Ramadan
# #### Day - 15 - Most common day when the Ramadan start

# %% [markdown]
# ## <center>Top affected countires</center>

# %%
Country_terror = terror['Country'].value_counts(dropna= False)

plt.subplots(figsize=(15,6))
sns.barplot(terror['Country'].value_counts()[:20].index, terror['Country'].value_counts()[:20].values,palette='RdBu')
plt.xticks(rotation=90)
plt.title('Top Affected Countries')
plt.show()

# %% [markdown]
# ## <center>Number of terrorist attacts around the world each year</center>

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year',data=terror,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year around the world')
plt.show()

# %% [markdown]
# ## <center>Visualization of the terror activities around the world</center>

# %%
# How many unique regions are in the dataset
regions = set(terror['Region'].unique())
print("Number of unique regions in dataset: ", len(regions))
# Out:
# Number of unique regions in dataset:  12

# %%
regions
# Out:
# {'Australasia & Oceania',
#  'Central America & Caribbean',
#  'Central Asia',
#  'East Asia',
#  'Eastern Europe',
#  'Middle East & North Africa',
#  'North America',
#  'South America',
#  'South Asia',
#  'Southeast Asia',
#  'Sub-Saharan Africa',
#  'Western Europe'}

# %%
world_geo = os.path.join('../gtd/','world-countries.json')
terror_world = terror[['Country','casualities']]
terror_world = terror_world.groupby(['Country'])['casualities'].sum().sort_values(ascending=False).reset_index()
terror_world.head()
# Out:
#        Country  casualities
# 0         Iraq     202982.0
# 1  Afghanistan      80213.0
# 2     Pakistan      64427.0
# 3        India      47108.0
# 4    Sri Lanka      29792.0

# %%
m = folium.Map(location=[0, 0],zoom_start=2,tiles='Mapbox Bright')

# %%
m.choropleth(
 geo_data=world_geo,
 name='choropleth',
 data=terror_world,
 columns=['Country', 'casualities'],
 key_on='feature.properties.name',
 fill_color='YlOrRd',
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Casualities in Numbers from 1970 to 2018'
)
folium.LayerControl().add_to(m)

# Save to html
m.save('world.html')

# %%
## There is problem with folium i guess 
## or with the json aka jameson ;/

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <center>What type of attack is most common in different regions</center>

# %%
pd.crosstab(terror.Region,terror.AttackType).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
fig.suptitle('Type of terror attacs in particular regions', fontsize=20)
plt.show()

# %% [markdown]
# ## <center>Most common types of attact in the most active region (Middle East & North Africa)</center>

# %%
# East region
east = terror[terror.Region == "Middle East & North Africa"]

pd.crosstab(east.Country,east.AttackType).plot.barh(stacked=True,width=1,color=sns.color_palette('CMRmap_r',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
fig.suptitle('Type of terror attacs in Middle East & North Africa', fontsize=20)
plt.show()

# %%
targetType = terror.Target_type.value_counts()
targetTypeList = sorted(list(zip(targetType.values, targetType.index)), reverse=True)
targetCount, target = zip(*targetTypeList)
targetCount, target = list(targetCount), list(target)

plt.figure(figsize=(20,8))
sns.barplot(x=target, y=targetCount, palette = sns.color_palette("YlGn_r", 21))
plt.xticks(rotation=35, ha="right")
plt.xlabel("Targets of Terrorists")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# # <center>Terrorism in Poland</center>

# %%
# Terrorism in Poland
terror_pol=terror[terror['Country']=='Poland']

# %%
terror_pol
# Out:
#         Year  Month  Day Country          Region          city   latitude  \
# 1040    1971     10    6  Poland  Eastern Europe         Opole  50.666667
# 8100    1979      4   17  Poland  Eastern Europe        Krakow  50.063730
# 14010   1981      8    1  Poland  Eastern Europe        Warsaw  52.229676
# 41172   1990      1   10  Poland  Eastern Europe        Warsaw  52.229676
# 42236   1990      4   22  Poland  Eastern Europe        Warsaw  52.229676
# 42875   1990      6    7  Poland  Eastern Europe        Gdansk  54.351993
# 42876   1990      6    7  Poland  Eastern Europe        Gdansk  54.351993
# 42877   1990      6    7  Poland  Eastern Europe        Gdansk  54.351993
# 44155   1990     10    1  Poland  Eastern Europe        Gdansk  54.351993
# 44182   1990     10    5  Poland  Eastern Europe        Warsaw  52.229676
# 51422   1992      5   13  Poland  Eastern Europe        Warsaw  52.229676
# 52782   1992      9    1  Poland  Eastern Europe        Warsaw  52.229676
# ...

# %%
 len(terror_pol)
# Out:
# 39

# %% [markdown]
# ## <center>The color and size of each point is according to the number of people killed in the attack. Click on each point to get more information about the attack.</center>

# %%
# Definig color of the point to highlight the number of Killed or Injured 
def color_point(x):
    if x>=30:
        color='red'
    elif ((x>0 and x<30)):
        color='blue'
    else:
        color='green'
    return color   

# Definig size of the point to highlight the number of Killed or Injured
def point_size(x):
    if (x>30 and x<100):
        size=2
    elif (x>=100 and x<500):
        size=8
    elif x>=500:
        size=16
    else:
        size=0.5
    return size  

terror_poland=terror[terror['Country']=='Poland']
terror_poland_fol=terror_poland.copy()
terror_poland_fol.dropna(subset=['latitude','longitude'],inplace=True)
location_ind=terror_poland_fol[['latitude','longitude']][:5000]
city_ind=terror_poland_fol['city'][:500]
killed_ind=terror_poland_fol['Killed'][:500]
wound_ind=terror_poland_fol['Wounded'][:500]
target_ind=terror_poland_fol['Target_type'][:500]

m2 = folium.Map(location=[52, 20],tiles='cartodbpositron',zoom_start=6)
for point in location_ind.index:
    folium.CircleMarker(list(location_ind.loc[point].values),popup='<b>City: </b>'+str(city_ind[point])+'<br><b>Killed: </b>'+str(killed_ind[point])+\
                        '<br><b>Injured: </b>'+str(wound_ind[point])+'<br><b>Target: </b>'+str(target_ind[point]),radius=point_size(killed_ind[point]),color=color_point(killed_ind[point]),fill_color=color_point(killed_ind[point])).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <center>Most common weapon type</center>

# %%
plt.subplots(figsize=(15,6))
sns.barplot(terror_pol['Weapon_type'].value_counts()[:20].index, terror_pol['Weapon_type'].value_counts()[:20].values,palette='RdBu')
plt.xticks(rotation=90)
plt.title('Most common weapon type')
plt.show()

# %%
ax = terror_pol['Weapon_type'].value_counts().plot(kind='bar', figsize=(10,7),
                                        color="coral", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("What is the most common weapon type in Poland", fontsize=18)
ax.set_ylabel("Number of attacks", fontsize=18);
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()-.03, i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')
